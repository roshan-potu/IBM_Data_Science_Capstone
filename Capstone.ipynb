# %% [markdown]
# # Data Science Coursera Capstone

# %% [markdown]
# This notebook shall be used for Capstone project of IBM Data Science Professional Certificate Course.

# %%
Import pandas as pd.
Import Numpy as np.
# Out:
#   File "<ipython-input-2-c8f32a52c0b7>", line 1
#     Import pandas as pd.
#                 ^
# SyntaxError: invalid syntax
